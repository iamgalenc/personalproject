# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('top100_kdrama.csv')
data.head()
# Out:
#    ID                        Title                                Genre  \
# 0   1               Move to Heaven                          Life, Drama
# 1   2           Weak Hero Class 1                  Action, Youth, Drama
# 2   3  Hospital Playlist Season 2         Romance, Life, Drama, Medical
# 3   4              Flower of Evil   Thriller, Romance, Crime, Melodrama
# 4   5           Hospital Playlist         Romance, Life, Drama, Medical
#
#                                                 Tags  \
# 0  Uncle-Nephew Relationship, Autism, Death, Sava...
# 1  Smart Male Lead, Bromance, School Bullying, Vi...
# 2  Multiple Mains, Band, Music, Strong Female Lea...
# 3  Deception, Family Secret, Mystery, Suspense, S...
# 4  Nice Male Lead, Multiple Mains, Slow Romance, ...
#
#                                             Synopsis  Rank  Popularity  Score  \
# 0  Han Geu Roo is a 20-year-old with Autism. He w...     8          94    9.2
# ...

# %%
data.count()
# Out:
# ID            100
# Title         100
# Genre         100
# Tags          100
# Synopsis      100
# Rank          100
# Popularity    100
# Score         100
# Episodes      100
# Duration      100
# Watchers      100
# Start_date    100
# End_date       88
# Day_aired     100
# Main Role     100
# dtype: int64

# %%
pd.DataFrame.sample(data)
# Out:
#     ID                  Title                   Genre  \
# 93  94  My Father Is Strange   Comedy, Romance, Drama
#
#                                                  Tags  \
# 93  Family Secret, Eccentric Female Lead, Fake Inc...
#
#                                              Synopsis  Rank  Popularity  \
# 93  This drama is about a family that lives on the...   344         372
#
#     Score  Episodes  Duration Watchers Start_date   End_date  \
# 93    8.6        52        66   27,397   3/4/2017  8/27/2017
#
#            Day_aired                                          Main Role
# 93  Saturday, Sunday  Kim Yeong Cheol, Ryu Soo Young, Lee Joon, Kim ...

# %%
df = pd.read_csv('top100_kdrama.csv', names=['Title','Rank'])
print(df)
# Out:
#                                                                                                                                                                                                                                                                  Title  \
# ID  Title                         Genre                               Tags                                               Synopsis                                           Rank Popularity Score Episodes Duration Watchers Start_date End_date             Day_aired
# 1   Move to Heaven                Life, Drama                         Uncle-Nephew Relationship, Autism, Death, Savan... Han Geu Roo is a 20-year-old with Autism. He wo... 8    94         9.2   10       52       64,103   5/14/2021  NaN                     Friday
# ...

# %%
data.describe()
# Out:
#                ID        Rank   Popularity       Score   Episodes    Duration
# count  100.000000  100.000000   100.000000  100.000000  100.00000  100.000000
# mean    50.500000  179.480000   319.730000    8.770000   18.08000   66.540000
# std     29.011492  106.655916   367.437313    0.159228   12.24636   13.105955
# min      1.000000    8.000000     1.000000    8.600000    6.00000   30.000000
# 25%     25.750000   90.750000    88.750000    8.600000   12.00000   60.000000
# 50%     50.500000  179.000000   194.500000    8.700000   16.00000   67.000000
# 75%     75.250000  262.250000   397.500000    8.900000   20.00000   75.000000
# max    100.000000  368.000000  2197.000000    9.200000  100.00000  100.000000
